# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Importing Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Series from lists

# %%
# string
country = ["India","Pakistan","USA","Nepal","Srilanka"]

pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
# Integer
runs = [13,24,56,78,100]

runs_ser = pd.Series(runs)
runs_ser
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
# Custom index
marks=[67,57,89,100]
subjects = ["Maths","English","Science","Hindi"]

pd.Series(marks,index=subjects)
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# dtype: int64

# %%
# Setting a name
marks=[67,57,89,100]
subjects = ["Maths","English","Science","Hindi"]

marks = pd.Series(marks,index=subjects,name="Saurav's Marks")
marks
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# Name: Saurav's Marks, dtype: int64

# %% [markdown]
# ### Series from dict

# %%
marks = {
    "Maths":67,
    "English":57,
    "Science":89,
    "Hindi":100
}

marks_series = pd.Series(marks,name="Saurav's Marks")
marks_series
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# Name: Saurav's Marks, dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
marks_series
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# Name: Saurav's Marks, dtype: int64

# %%
# size
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# "Saurav's Marks"

# %%
# is_unique
marks_series.is_unique
# Out:
# True

# %%
pd.Series([1,1,2,3,5]).is_unique
# Out:
# False

# %%
# index
marks_series.index
# Out:
# Index(['Maths', 'English', 'Science', 'Hindi'], dtype='object')

# %%
runs_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
type(runs_ser.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
# values
marks_series.values
# Out:
# array([ 67,  57,  89, 100], dtype=int64)

# %%
runs_ser.values
# Out:
# array([ 13,  24,  56,  78, 100], dtype=int64)

# %%
type(marks_series.values)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Series using read_csv

# %%
# with one col

# %%
pd.read_csv("subs.csv")
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
type(pd.read_csv("subs.csv"))
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv("subs.csv",squeeze=True)
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
type(pd.read_csv("subs.csv",squeeze=True))
# Out:
# pandas.core.series.Series

# %%
subs = pd.read_csv("subs.csv",squeeze=True)
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# with 2 col

# %%
vk = pd.read_csv("kohli_ipl.csv",index_col="match_no",squeeze=True)
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv("bollywood.csv",index_col="movie",squeeze=True)
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series methods

# %%
# head and tail

# %%
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
vk.head(3)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# Name: runs, dtype: int64

# %%
vk.tail()
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
vk.tail(10)
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# sample

# %%
movies.sample()
# Out:
# movie
# Kyaa Kool Hai Hum    Tusshar Kapoor
# Name: lead, dtype: object

# %%
movies.sample(5)
# Out:
# movie
# Mumbai Mast Kallander              Mohsin
# ABCD 2                        Prabhu Deva
# Challo Driver            Vickrant Mahajan
# Dor (film)                   Ayesha Takia
# Yeh Lamhe Judaai Ke        Shah Rukh Khan
# Name: lead, dtype: object

# %%
# value_counts

# %%
movies.value_counts()
# Out:
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Ishaan Manhaas        1
# Kamal Rashid Khan     1
# Hugh Bonneville       1
# Shahbaaz Khan         1
# J.D. Chakravarthi     1
# Name: lead, Length: 566, dtype: int64

# %%
# sort_values

# %%
vk.sort_values()
# Out:
# match_no
# 87       0
# 211      0
# 207      0
# 206      0
# 91       0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
vk.sort_values(ascending=False)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 164    100
# 120    100
#       ...
# 93       0
# 211      0
# 130      0
# 8        0
# 135      0
# Name: runs, Length: 215, dtype: int64

# %%
vk.sort_values(ascending=False).head(1)
# Out:
# match_no
# 128    113
# Name: runs, dtype: int64

# %%
vk.sort_values(ascending=False).head(1).values
# Out:
# array([113], dtype=int64)

# %%
vk.sort_values(ascending=False).head(1).values[0]
# Out:
# 113

# %%
# sort_index

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies.sort_index(ascending=False)
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series Maths Methods

# %%
# count -> It ignores missing values

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk.count()
# Out:
# 215

# %%
# sum

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.sum()
# Out:
# 49510

# %%
# product

# %%
subs.product()
# Out:
# 0

# %%
# mean

# %%
subs.mean()
# Out:
# 135.64383561643837

# %%
# median

# %%
vk.median()
# Out:
# 24.0

# %%
# mode

# %%
movies.mode()
# Out:
# 0    Akshay Kumar
# dtype: object

# %%
# std

# %%
subs.std()
# Out:
# 62.6750230372527

# %%
# var

# %%
subs.var()
# Out:
# 3928.1585127201565

# %%
# min

# %%
subs.min()
# Out:
# 33

# %%
# max

# %%
subs.max()
# Out:
# 396

# %%
# describe

# %%
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# ### Series Indexing

# %%
# integer indexing

# %%
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
x[0]
# Out:
# 12

# %%
x[1]
# Out:
# 13

# %%
# negative indexing
x[-1]
# Series does not work with negative indexes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\saura\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-60055cb99cf0> in <module>
#       1 # negative indexing
# ----> 2 x[-1]
#
# c:\users\saura\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     822
#     823         elif key_is_scalar:
# --> 824             return self._get_value(key)
#     825
#     826         if is_hashable(key):
# ...

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies[0]
# Out:
# 'Vicky Kaushal'

# %%
movies["Uri: The Surgical Strike"]
# Out:
# 'Vicky Kaushal'

# %%
movies[-1]
# Out:
# 'Akshay Kumar'

# %% [markdown]
# ##### If it is named index [which is string] then negative indexes as well as positive indexes also work

# %% [markdown]
# ##### If it is named index [which is number] then negative indexes does not work

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\saura\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-8ecb27b68523> in <module>
# ...

# %%
marks_series
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# Name: Saurav's Marks, dtype: int64

# %%
marks_series[-1]
# Out:
# 100

# %%
# slicing

# %%
vk[5:16]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
vk[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movies[-5:]
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
movies[::2]
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: object

# %%
# Fancy Indexing

# %%
vk[[1,3,4]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# Name: runs, dtype: int64

# %%
# indexing with labels

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies["Aankhen (2002 film)"]
# Out:
# 'Amitabh Bachchan'

# %% [markdown]
# ### Editing Series

# %%
# using indexing

# %%
marks_series
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# Name: Saurav's Marks, dtype: int64

# %%
marks_series[1] = 100

# %%
marks_series
# Out:
# Maths       67
# English    100
# Science     89
# Hindi      100
# Name: Saurav's Marks, dtype: int64

# %%
# what if an index does not exist

# %%
marks_series["sst"] = 90

# %%
marks_series
# Out:
# Maths       67
# English    100
# Science     89
# Hindi      100
# sst         90
# Name: Saurav's Marks, dtype: int64

# %%
# slicing

# %%
runs_ser
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
runs_ser[2:4] = [100,100]
runs_ser
# Out:
# 0     13
# 1     24
# 2    100
# 3    100
# 4    100
# dtype: int64

# %%
# fancy indexing

# %%
runs_ser
# Out:
# 0     13
# 1     24
# 2    100
# 3    100
# 4    100
# dtype: int64

# %%
runs_ser[[0,3,4]] = [0,0,0]
runs_ser
# Out:
# 0      0
# 1     24
# 2    100
# 3      0
# 4      0
# dtype: int64

# %%
# using index labels

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies["Why Cheat India"] = "Emran"

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                                    Emran
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series with Python Functionalities

# %%
# len

# %%
len(subs)
# Out:
# 365

# %%
# type

# %%
type(subs)
# Out:
# pandas.core.series.Series

# %%
# dir

# %%
dir(subs)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
# sorted

# %%
sorted(subs)
# Out:
# [33,
#  33,
#  35,
#  37,
#  39,
#  40,
#  40,
#  40,
#  40,
#  42,
#  42,
#  43,
#  44,
#  44,
#  44,
#  45,
#  46,
#  46,
#  48,
#  49,
#  49,
#  49,
#  49,
#  50,
#  50,
#  50,
#  51,
#  54,
#  56,
#  56,
#  56,
#  56,
#  57,
#  61,
#  62,
#  64,
#  65,
#  65,
#  66,
#  66,
#  66,
#  66,
#  67,
#  68,
#  70,
#  70,
#  70,
#  71,
#  71,
#  72,
#  72,
#  72,
#  72,
#  72,
#  73,
#  74,
#  74,
#  75,
#  76,
#  76,
#  76,
#  76,
#  77,
#  77,
#  78,
#  78,
#  78,
#  79,
#  79,
#  80,
#  80,
#  80,
#  81,
#  81,
#  82,
#  82,
#  83,
#  83,
#  83,
#  84,
#  84,
#  84,
#  85,
#  86,
#  86,
#  86,
#  87,
#  87,
#  87,
#  87,
#  88,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  89,
#  90,
#  90,
#  90,
#  90,
#  91,
#  92,
#  92,
#  92,
#  93,
#  93,
#  93,
#  93,
#  95,
#  95,
#  96,
#  96,
#  96,
#  96,
#  97,
#  97,
#  98,
#  98,
#  99,
#  99,
#  100,
#  100,
#  100,
#  101,
#  101,
#  101,
#  102,
#  102,
#  103,
#  103,
#  104,
#  104,
#  104,
#  105,
#  105,
#  105,
#  105,
#  105,
# ...

# %%
# max

# %%
max(subs)
# Out:
# 396

# %%
# min

# %%
min(subs)
# Out:
# 33

# %%
# type conversion

# %%
marks_series
# Out:
# Maths       67
# English    100
# Science     89
# Hindi      100
# sst         90
# Name: Saurav's Marks, dtype: int64

# %%
list(marks_series)
# Out:
# [67, 100, 89, 100, 90]

# %%
dict(marks_series)
# Out:
# {'Maths': 67, 'English': 100, 'Science': 89, 'Hindi': 100, 'sst': 90}

# %%
# membership operator

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                                    Emran
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
"Hum Tumhare Hain Sanam" in movies
# Out:
# True

# %%
"Anupam Kher" in movies
# Out:
# False

# %%
"Anupam Kher" in movies.values
# Out:
# True

# %%
# looping

# %%
for i in movies:
    print(i)
# Out:
# Vicky Kaushal
# Vicky Ahuja
# Anupam Kher
# Emran
# Mona Ambegaonkar
# Geetika Vidya Ohlyan
# Arshad Warsi
# Radhika Apte
# Kangana Ranaut
# Nawazuddin Siddiqui
# Ali Asgar
# Ranveer Singh
# Prit Kamani
# Ajay Devgn
# Sushant Singh Rajput
# Amitabh Bachchan
# Abhimanyu Dasani
# Talha Arshad Reshi
# Nawazuddin Siddiqui
# Garima Agarwal
# Rasika Agashe
# Barun Sobti
# Akshay Kumar
# Zaheer Iqbal
# Vidyut Jammwal
# Deepika Amin
# Manav Kaul
# Naseeruddin Shah
# Varun Dhawan
# Shreyas Talpade
# Tiger Shroff
# Boman Irani
# Ajay Devgn
# Arjun Kapoor
# Gavie Chahal
# Prabhu Deva
# Shahid Kapoor
# Ayushmann Khurrana
# Anupam Kher
# Karanvir Bohra
# Hrithik Roshan
# Jimmy Sheirgill
# John Abraham
# Rishi Kapoor
# Kangana Ranaut
# Natalia Janoszek
# Diljit Dosanjh
# Sidharth Malhotra
# Rajeev Khandelwal
# Zaira Wasim
# Akshay Kumar
# Jacqueline Fernandez
# Ayushmann Khurrana
# Akshaye Khanna
# Sonam Kapoor
# Karan Deol
# Sanjay Dutt
# Bhavesh Kumar
# Sanaya Irani
# Ayushmann Khurrana
# ...

# %%
for i in movies.index:
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
for i,j in movies.items():
    print(i+":",j)
# Out:
# Uri: The Surgical Strike: Vicky Kaushal
# Battalion 609: Vicky Ahuja
# The Accidental Prime Minister (film): Anupam Kher
# Why Cheat India: Emran
# Evening Shadows: Mona Ambegaonkar
# Soni (film): Geetika Vidya Ohlyan
# Fraud Saiyaan: Arshad Warsi
# Bombairiya: Radhika Apte
# Manikarnika: The Queen of Jhansi: Kangana Ranaut
# Thackeray (film): Nawazuddin Siddiqui
# Amavas: Ali Asgar
# Gully Boy: Ranveer Singh
# Hum Chaar: Prit Kamani
# Total Dhamaal: Ajay Devgn
# Sonchiriya: Sushant Singh Rajput
# Badla (2019 film): Amitabh Bachchan
# Mard Ko Dard Nahi Hota: Abhimanyu Dasani
# Hamid (film): Talha Arshad Reshi
# Photograph (film): Nawazuddin Siddiqui
# Risknamaa: Garima Agarwal
# Mere Pyare Prime Minister: Rasika Agashe
# 22 Yards: Barun Sobti
# Kesari (film): Akshay Kumar
# Notebook (2019 film): Zaheer Iqbal
# Junglee (2019 film): Vidyut Jammwal
# Gone Kesh: Deepika Amin
# Albert Pinto Ko Gussa Kyun Aata Hai?: Manav Kaul
# The Tashkent Files: Naseeruddin Shah
# Kalank: Varun Dhawan
# ...

# %%
# Arithmetic Operators

# %%
marks_series
# Out:
# Maths       67
# English    100
# Science     89
# Hindi      100
# sst         90
# Name: Saurav's Marks, dtype: int64

# %%
100 - marks_series
# Out:
# Maths      33
# English     0
# Science    11
# Hindi       0
# sst        10
# Name: Saurav's Marks, dtype: int64

# %%
# Relational Operators

# %%
vk >= 50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# ### Boolean Indexing on Series

# %%
# Find no of 50's by kohli
len(vk[vk>=50])
# Out:
# 50

# %%
(vk>=50).sum()
# Out:
# 50

# %%
# find number of ducks
vk[vk == 0]
# Out:
# match_no
# 8      0
# 87     0
# 91     0
# 93     0
# 130    0
# 135    0
# 206    0
# 207    0
# 211    0
# Name: runs, dtype: int64

# %%
len(vk[vk == 0])
# Out:
# 9

# %%
(vk[vk == 0]).sum()
# Out:
# 0

# %%
# Count number of day when I had more than 200 subs a day

# %%
subs[subs>200]
# Out:
# 165    225
# 166    249
# 167    265
# 168    306
# 169    261
# 170    222
# 225    224
# 226    254
# 227    214
# 228    236
# 229    261
# 230    247
# 231    207
# 232    254
# 233    301
# 234    233
# 240    202
# 246    259
# 248    213
# 249    210
# 252    216
# 275    228
# 276    237
# 277    276
# 279    290
# 280    295
# 281    245
# 282    241
# 283    267
# 284    269
# 285    211
# 287    206
# 288    202
# 290    236
# 291    222
# 292    203
# 312    230
# 318    244
# 324    243
# 325    227
# 326    259
# 330    396
# 331    312
# 332    268
# 333    229
# 337    221
# 338    225
# 339    221
# 340    202
# 344    276
# 345    258
# 346    219
# 347    212
# 351    220
# 354    204
# 358    210
# 359    209
# 360    231
# 361    226
# Name: Subscribers gained, dtype: int64

# %%
len(subs[subs>200])
# Out:
# 59

# %%
# find actors who have done more than 20 movies

# %%
movies.value_counts()
# Out:
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Ronit Roy             1
# Ishaan Manhaas        1
# Kamal Rashid Khan     1
# Hugh Bonneville       1
# J.D. Chakravarthi     1
# Name: lead, Length: 567, dtype: int64

# %%
movies.value_counts() > 20
# Out:
# Akshay Kumar          True
# Amitabh Bachchan      True
# Ajay Devgn            True
# Salman Khan           True
# Sanjay Dutt           True
#                      ...
# Ronit Roy            False
# Ishaan Manhaas       False
# Kamal Rashid Khan    False
# Hugh Bonneville      False
# J.D. Chakravarthi    False
# Name: lead, Length: 567, dtype: bool

# %%
(movies.value_counts() > 20).sum()
# Out:
# 6

# %%
movies.value_counts()[movies.value_counts() > 20]
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Name: lead, dtype: int64

# %% [markdown]
# ### Plotting Graphs on Series

# %%
subs.plot()
# Out:
# <AxesSubplot:>

# %%
marks_series.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
movies.value_counts().head(20).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
movies.value_counts().head(20).plot(kind="pie",autopct="%.2f%%")
# Out:
# <AxesSubplot:ylabel='lead'>
